# %%
import math, pandas as pd, numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

# %%
mDf = pd.read_csv('murder_per_100000_people.csv')
hDf = pd.read_csv('hapiscore_whr.csv')
fDf = pd.read_csv('food_supply_kilocalories_per_person_and_day.csv')
cDf = pd.read_csv('corruption_perception_index_cpi.csv')

# %%
# I need to choose countries and years that will work for all data sets
# Needs to be from 2011-2015 because that is the year range that works for them all
# Chose 2011 -most values there in this year
# Dropped null values from each dataset for the 2011 year to find which countries work -48 possible countries

totDataSet = pd.DataFrame({"Country" : fDf["country"], "Food Supply" : fDf["2011"], "Happiness" : hDf["2011"], "Murder" : mDf["2011"], "Percieved Non-Corruption" : cDf["2011"]})
totDataSet.dropna(inplace = True)
totDataSet
# Out:
#                       Country  Food Supply  Happiness  Murder  \
# 2                     Albania       3180.0       55.1   1.510
# 4        United Arab Emirates       3230.0       64.7   1.230
# 5                   Argentina       3200.0       43.2   0.369
# 7         Antigua and Barbuda       2290.0       74.0   1.090
# 8                   Australia       3260.0       49.1   1.230
# 17     Bosnia and Herzegovina       3050.0       57.5   1.270
# 19                     Belize       2740.0       60.2   0.437
# 26   Central African Republic       2120.0       66.0   2.060
# 27                     Canada       3490.0       50.9   0.746
# 32              Cote d'Ivoire       2780.0       63.7   0.312
# 36                 Cape Verde       2590.0       61.8   0.568
# 37                 Costa Rica       2850.0       63.3   4.410
# 38                       Cuba       3350.0       67.0   1.340
# 40             Czech Republic       3240.0       75.2   0.233
# 41                    Germany       3500.0       47.5   0.789
# 43                   Dominica       2950.0       59.6   1.300
# 48                      Egypt       3560.0       74.2   0.231
# 49                      Spain       3170.0       66.5   0.952
# 50                    Estonia       3230.0       39.7   1.170
# 51                   Ethiopia       2120.0       68.8   0.830
# 52                    Finland       3320.0       42.5   0.332
# 53                       Fiji       2930.0       50.6   1.800
# 54                     France       3460.0       36.5   0.698
# 56             United Kingdom       3400.0       51.0   1.940
# 57                    Georgia       2840.0       58.6   0.262
# 59                     Guinea       2560.0       54.8   4.790
# 61              Guinea-Bissau       2330.0       60.3   0.983
# 62                     Greece       3400.0       44.1   0.531
# 65                     Guyana       2730.0       47.2   3.930
# 66           Hong Kong, China       3280.0       69.6   0.188
# 67                   Honduras       2630.0       46.1   4.980
# 68                    Croatia       3000.0       46.6   4.980
# 70                    Hungary       3010.0       71.1   1.500
# 71                  Indonesia       2770.0       58.4   1.520
# 75                       Iraq       2530.0       57.6   2.350
# 76                    Iceland       3400.0       45.5   0.747
# 78                      Italy       3580.0       39.0   0.830
# 79                    Jamaica       2750.0       60.0   0.566
# 80                     Jordan       3140.0       62.2   1.230
# 85                   Cambodia       2430.0       42.2   0.788
# 87        St. Kitts and Nevis       2480.0       57.7   0.970
# 90                        Lao       2380.0       49.7   1.710
# 95                    Lesotho       2550.0       46.4   1.480
# 98                     Latvia       3110.0       44.4   0.909
# 99               Macao, China       2910.0       52.2   0.608
# 100                   Morocco       3370.0       48.9   0.657
# 102                Madagascar       2060.0       46.7   4.310
# 107                     Malta       3380.0       38.0   1.230
#
#      Percieved Non-Corruption
# 2                        33.0
# 4                        35.0
# 5                        34.0
# 7                        69.0
# 8                        27.0
# 17                       42.0
# 19                       34.0
# 26                       84.0
# 27                       86.0
# 32                       21.0
# 36                       60.0
# 37                       54.0
# 38                       48.0
# 40                       49.0
# 41                       79.0
# 43                       58.0
# 48                       32.0
# 49                       25.0
# 50                       65.0
# 51                       64.0
# 52                       33.0
# 53                       90.0
# 54                       71.0
# 56                       74.0
# 57                       52.0
# 59                       24.0
# 61                       25.0
# 62                       20.0
# 65                       33.0
# 66                       28.0
# 67                       77.0
# 68                       28.0
# 70                       19.0
# 71                       55.0
# 75                       28.0
# 76                       18.0
# 78                       60.0
# 79                       42.0
# 80                       38.0
# 85                       24.0
# 87                       56.0
# 90                       21.0
# 95                       40.0
# 98                       80.0
# 99                       49.0
# 100                      37.0
# 102                      32.0
# 107                      57.0

# %%
totDataSet.plot(kind = "scatter", x = "Food Supply", y = "Percieved Non-Corruption")
# Out:
# <AxesSubplot:xlabel='Food Supply', ylabel='Percieved Non-Corruption'>

# %%
# Calculate info
def findInfo(data):
    data.sort()
    diffSquared = []
    outliers = []
    
    # Find variance
    mean = sum(data) / len(data)
    for i in data:
        diffSquared.append((i - mean) ** 2)
    pVar = sum(diffSquared) / len(diffSquared)
    sVar = sum(diffSquared) / (len(diffSquared) - 1)
    
    # Find quartiles and IQR
    term = (len(data) + 1)
    q1 = (data[int(term / 4) - 1] + data[math.ceil(term / 4) - 1]) / 2 # subtracting 1 because of computer indexing
    q2 = (data[int(term / 2) - 1] + data[math.ceil(term / 2) - 1]) / 2
    q3 = (data[int(3 * term / 4) - 1] + data[math.ceil(3 * term / 4) - 1]) / 2
    iqr = q3 - q1
    
    # Find outliers
    lowerFence = q1 - (1.5 * iqr)
    higherFence = q3 + (1.5 * iqr)
    for i in data:
        if (i < lowerFence or i > higherFence) and str(i) not in outliers:
            outliers.append(i)
    
    # returns in order: mean, pop. variance, pop. standard dev, sam. variance, sam. standard deviation, quartiles, iqr, fences, outliers
    return mean, pVar, math.sqrt(pVar), sVar, math.sqrt(sVar), (q1, q2, q3), iqr, lowerFence, higherFence, outliers

# %%
def pairsInfo(xVals, yVals):
    # variables
    n = len(xVals)
    sumX = sum(xVals)
    sumY = sum(yVals)
    sumXSquared = 0
    sumYSquared = 0
    sumXY = 0
    corrCoeff = 0
    corrType = ["none", "weak", "moderate", "strong", "perfect"]
    corrSign = "positive"
    lstSqrsA = 0
    lstSqrsB = 0
    lstSqrsLn = ""
    
    # set proper values for the sum values
    for i in range(n):
        sumXSquared += (xVals[i]) ** 2
        sumYSquared += (yVals[i]) ** 2
        sumXY += (xVals[i]) * yVals[i]
    
    # proper values for coefficient and relation-type
    corrCoeff = ((n * sumXY) - (sumX) * (sumY))/(math.sqrt((n * sumXSquared) - (sumX) ** 2) * math.sqrt((n * sumYSquared) - (sumY) ** 2))
    cc = abs(corrCoeff)
    
    if cc == 0:
        corrType = corrType[0]
    elif cc < (1 / 3) or cc > 0:
        corrType = corrType[1]
    elif cc < (2 / 3) and cc >= (1 / 3):
        corrType = corrType[2]
    elif cc < 1 and cc >= (2 / 3):
        corrType = corrType[3]
    else:
        corrType = corrType[4]
    
    if corrCoeff < 0:
        corrSign = "negative"
    elif corrCoeff == 0:
        corrSign = ""
    
    # linear regression real values
    lstSqrsA = (n * (sumXY) - (sumX * sumY)) / ((n * sumXSquared) - (sumX) ** 2)
    lstSqrsB = (sumY / n) - (lstSqrsA * (sumX / n))
    lstSqrsLn = "y = %.5fx + %.5f" %(lstSqrsA, lstSqrsB)
    
    return corrCoeff, corrType, corrSign, lstSqrsA, lstSqrsLn

# %%
fcRelInfo = pairsInfo(totDataSet["Food Supply"].tolist(), totDataSet["Percieved Non-Corruption"].tolist())
print("The correlation coefficient is %f which indicates a %s, %s relationship." %(fcRelInfo[0], fcRelInfo[1], fcRelInfo[2]))
print("The equation of the line of best fit is " + fcRelInfo[4] + ".")
# Out:
# The correlation coefficient is 0.035448 which indicates a weak, positive relationship.
# The equation of the line of best fit is y = 0.00173x + 40.92516.

# %%
pd.DataFrame({"Food Supply" : totDataSet["Food Supply"], "Percieved Non-Corruption" : totDataSet["Percieved Non-Corruption"]})
# Out:
#      Food Supply  Percieved Non-Corruption
# 2         3180.0                      33.0
# 4         3230.0                      35.0
# 5         3200.0                      34.0
# 7         2290.0                      69.0
# 8         3260.0                      27.0
# 17        3050.0                      42.0
# 19        2740.0                      34.0
# 26        2120.0                      84.0
# 27        3490.0                      86.0
# 32        2780.0                      21.0
# 36        2590.0                      60.0
# 37        2850.0                      54.0
# 38        3350.0                      48.0
# 40        3240.0                      49.0
# 41        3500.0                      79.0
# 43        2950.0                      58.0
# 48        3560.0                      32.0
# 49        3170.0                      25.0
# 50        3230.0                      65.0
# 51        2120.0                      64.0
# 52        3320.0                      33.0
# 53        2930.0                      90.0
# 54        3460.0                      71.0
# 56        3400.0                      74.0
# 57        2840.0                      52.0
# 59        2560.0                      24.0
# 61        2330.0                      25.0
# 62        3400.0                      20.0
# 65        2730.0                      33.0
# 66        3280.0                      28.0
# 67        2630.0                      77.0
# 68        3000.0                      28.0
# 70        3010.0                      19.0
# 71        2770.0                      55.0
# 75        2530.0                      28.0
# 76        3400.0                      18.0
# 78        3580.0                      60.0
# 79        2750.0                      42.0
# 80        3140.0                      38.0
# 85        2430.0                      24.0
# 87        2480.0                      56.0
# 90        2380.0                      21.0
# 95        2550.0                      40.0
# 98        3110.0                      80.0
# 99        2910.0                      49.0
# 100       3370.0                      37.0
# 102       2060.0                      32.0
# 107       3380.0                      57.0
